# %% [markdown]
# # Importing the libraries

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# # Read the Data Set and preapred Data Frame

# %%
df = pd.read_excel(r"D:\Sreenath\DSWorkspace\LungCap.xls")
df
# Out:
#      LungCap(cc)  Age( years)  Height(inches) Smoke  Gender Caesarean
# 0          6.475            6            62.1    no    male        no
# 1         10.125           18            74.7   yes  female        no
# 2          9.550           16            69.7    no  female       yes
# 3         11.125           14            71.0    no    male        no
# 4          4.800            5            56.9    no    male        no
# ..           ...          ...             ...   ...     ...       ...
# 720        5.725            9            56.0    no  female        no
# 721        9.050           18            72.0   yes    male       yes
# 722        3.850           11            60.5   yes  female        no
# 723        9.825           15            64.9    no  female        no
# 724        7.100           10            67.7    no    male        no
#
# [725 rows x 6 columns]

# %% [markdown]
# # Display the First 5 rows

# %%
df.head()
# Out:
#    LungCap(cc)  Age( years)  Height(inches) Smoke  Gender Caesarean
# 0        6.475            6            62.1    no    male        no
# 1       10.125           18            74.7   yes  female        no
# 2        9.550           16            69.7    no  female       yes
# 3       11.125           14            71.0    no    male        no
# 4        4.800            5            56.9    no    male        no

# %% [markdown]
# # Display Last 5 rows

# %%
df.tail()
# Out:
#      LungCap(cc)  Age( years)  Height(inches) Smoke  Gender Caesarean
# 720        5.725            9            56.0    no  female        no
# 721        9.050           18            72.0   yes    male       yes
# 722        3.850           11            60.5   yes  female        no
# 723        9.825           15            64.9    no  female        no
# 724        7.100           10            67.7    no    male        no

# %% [markdown]
# # Display from 20 to 45 rows

# %%
df[20:46]
#df['Age( years)'].mean()
# Out:
#     LungCap(cc)  Age( years)  Height(inches) Smoke  Gender Caesarean
# 20        3.975            6            57.3    no    male        no
# 21        5.325            8            59.7    no  female        no
# 22       10.025           16            72.4    no    male        no
# 23        8.725           11            68.0    no    male       yes
# 24        9.375           11            65.7    no  female        no
# 25        8.350           12            61.3    no    male       yes
# 26        6.750           12            60.7    no  female        no
# 27        9.025            9            65.6    no    male        no
# 28        1.125            4            48.7    no  female        no
# 29       10.475           18            72.0   yes  female        no
# 30        4.650            4            53.7    no  female        no
# 31        7.725           13            64.7    no    male        no
# 32       10.600           13            69.3    no    male        no
# ...

# %% [markdown]
# # Display Information of the Data Set

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 725 entries, 0 to 724
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   LungCap(cc)     725 non-null    float64
#  1   Age( years)     725 non-null    int64
#  2   Height(inches)  725 non-null    float64
#  3   Smoke           725 non-null    object
#  4   Gender          725 non-null    object
#  5   Caesarean       725 non-null    object
# dtypes: float64(2), int64(1), object(3)
# memory usage: 34.1+ KB

# %% [markdown]
# # Description of the Data Set

# %%
df.describe()
#df.describe(include = 'all')
# Out:
#        LungCap(cc)  Age( years)  Height(inches)
# count   725.000000   725.000000      725.000000
# mean      7.863148    12.326897       64.836276
# std       2.662008     4.004750        7.202144
# min       0.507000     3.000000       45.300000
# 25%       6.150000     9.000000       59.900000
# 50%       8.000000    13.000000       65.400000
# 75%       9.800000    15.000000       70.300000
# max      14.675000    19.000000       81.800000

# %% [markdown]
# # Names of the columns of the Data Set

# %%
# Option 1
df.columns
#option 2
list(df.columns)
#option 3
for i in df.columns:
    print(i)
# Out:
# LungCap(cc)
# Age( years)
# Height(inches)
# Smoke
# Gender
# Caesarean

# %% [markdown]
# # No of Males and number of females under Gender column in the Data Set

# %%
df.groupby(['Gender']).size()
# Out:
# Gender
# female    358
# male      367
# dtype: int64

# %% [markdown]
# # Check the missing values in Data Set

# %%
df.isnull().sum()
#another way of doing the same
df.isnull().values.any()
# Out:
# False

# %% [markdown]
# # Print only LungCap & Age columns

# %%
df.loc[:,['LungCap(cc)','Age( years)']]
#df[['LungCap(cc)','Age( years)']]
# Out:
#      LungCap(cc)  Age( years)
# 0          6.475            6
# 1         10.125           18
# 2          9.550           16
# 3         11.125           14
# 4          4.800            5
# ..           ...          ...
# 720        5.725            9
# 721        9.050           18
# 722        3.850           11
# 723        9.825           15
# 724        7.100           10
#
# [725 rows x 2 columns]

# %%
df.loc[[556, 720],['LungCap(cc)','Age( years)']]
# Out:
#      LungCap(cc)  Age( years)
# 556        2.725            6
# 720        5.725            9

# %% [markdown]
# # Select rows 2 to 8 and columns 2 to 5

# %%
df.iloc[2:8, 2:5]
# Out:
#    Height(inches) Smoke  Gender
# 2            69.7    no  female
# 3            71.0    no    male
# 4            56.9    no    male
# 5            58.7    no  female
# 6            63.3    no    male
# 7            70.4    no    male

# %% [markdown]
# # Select every second row after the fourth roaw and all columns

# %%
df.iloc[4::2,:]
# Out:
#      LungCap(cc)  Age( years)  Height(inches) Smoke  Gender Caesarean
# 4          4.800            5            56.9    no    male        no
# 6          4.950            8            63.3    no    male       yes
# 8          8.875           15            70.5    no    male        no
# 10        11.500           19            76.4    no    male       yes
# 12         6.525           12            57.5    no    male        no
# ..           ...          ...             ...   ...     ...       ...
# 716        7.075           11            66.7    no    male       yes
# 718        7.175           17            68.8    no    male       yes
# 720        5.725            9            56.0    no  female        no
# 722        3.850           11            60.5   yes  female        no
# 724        7.100           10            67.7    no    male        no
#
# [361 rows x 6 columns]

# %% [markdown]
# # Select every row upto the 4th row and all columns

# %%
df.iloc[:4,:]
# Out:
#    LungCap(cc)  Age( years)  Height(inches) Smoke  Gender Caesarean
# 0        6.475            6            62.1    no    male        no
# 1       10.125           18            74.7   yes  female        no
# 2        9.550           16            69.7    no  female       yes
# 3       11.125           14            71.0    no    male        no

# %% [markdown]
# # Select every 2nd row and every 2nd column

# %%
df.iloc[::2,::2]
#df.loc[::2,::2]
# Out:
#      LungCap(cc)  Height(inches)  Gender
# 0          6.475            62.1    male
# 2          9.550            69.7  female
# 4          4.800            56.9    male
# 6          4.950            63.3    male
# 8          8.875            70.5    male
# ..           ...             ...     ...
# 716        7.075            66.7    male
# 718        7.175            68.8    male
# 720        5.725            56.0  female
# 722        3.850            60.5  female
# 724        7.100            67.7    male
#
# [363 rows x 3 columns]

# %% [markdown]
# # Select rows where Age is greater than 12

# %%
#df["Age( years)"] > 12
df[df["Age( years)"] > 12]
# Out:
#      LungCap(cc)  Age( years)  Height(inches) Smoke  Gender Caesarean
# 1         10.125           18            74.7   yes  female        no
# 2          9.550           16            69.7    no  female       yes
# 3         11.125           14            71.0    no    male        no
# 8          8.875           15            70.5    no    male        no
# 10        11.500           19            76.4    no    male       yes
# ..           ...          ...             ...   ...     ...       ...
# 715        8.725           19            68.4    no  female        no
# 717        8.825           16            71.3   yes  female        no
# 718        7.175           17            68.8    no    male       yes
# 721        9.050           18            72.0   yes    male       yes
# 723        9.825           15            64.9    no  female        no
#
# [366 rows x 6 columns]

# %% [markdown]
# # Select Rowas where age is greater than 12 and less than 16

# %%
#(df["Age( years)"]) > 12 | (df["Age( years)"] <16)
df[(df["Age( years)"]) > 12 & (df["Age( years)"] <16)]
# Out:
#      LungCap(cc)  Age( years)  Height(inches) Smoke  Gender Caesarean
# 0          6.475            6            62.1    no    male        no
# 1         10.125           18            74.7   yes  female        no
# 2          9.550           16            69.7    no  female       yes
# 3         11.125           14            71.0    no    male        no
# 4          4.800            5            56.9    no    male        no
# ..           ...          ...             ...   ...     ...       ...
# 720        5.725            9            56.0    no  female        no
# 721        9.050           18            72.0   yes    male       yes
# 722        3.850           11            60.5   yes  female        no
# 723        9.825           15            64.9    no  female        no
# 724        7.100           10            67.7    no    male        no
#
# [725 rows x 6 columns]
